# %%
from roboflow import Roboflow
rf = Roboflow(api_key="bkvGKws3U501v3L3HEGw")
project = rf.workspace("iit-pallakkad").project("detect-indian-currency")
version = project.version(2)
dataset = version.download("yolo26")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# Downloading Dataset Version Zip in Detect-Indian-Currency-2 to yolo26:: 100%|██████████| 754304/754304 [08:28<00:00, 1483.60it/s]
# Extracting Dataset Version Zip to Detect-Indian-Currency-2 in yolo26:: 100%|██████████| 17930/17930 [00:08<00:00, 2037.37it/s]

# %%
print(dataset.location)
# Out:
# c:\Users\anasm\OneDrive\Documents\Projectss\Main-Project-SW\Detect-Indian-Currency-2
